# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
final_data = []
counter = 0
for i in os.listdir('data/categorical_data'):
    data = pd.read_csv("data/categorical_data/"+i)
    data['label'] = [counter]*data.shape[0]
    final_data.append(data)
    counter += 1

data = pd.concat(final_data, axis = 0, ignore_index = True)
data
# Out:
#        0_x   0_y  0_z  0_vis   1_x   1_y  1_z  1_vis   2_x   2_y  ...  18_vis  \
# 0    -0.63 -0.36 1.04   1.00 -0.66 -0.34 0.96   1.00 -0.68 -0.33  ...    0.95
# 1    -0.64 -0.36 0.83   1.00 -0.66 -0.34 0.75   1.00 -0.68 -0.33  ...    0.98
# 2    -0.64 -0.36 0.78   1.00 -0.66 -0.34 0.71   1.00 -0.68 -0.33  ...    0.98
# 3    -0.63 -0.36 0.72   1.00 -0.66 -0.33 0.64   1.00 -0.68 -0.33  ...    0.98
# 4    -0.64 -0.36 0.85   1.00 -0.66 -0.34 0.75   1.00 -0.69 -0.33  ...    0.99
# ...    ...   ...  ...    ...   ...   ...  ...    ...   ...   ...  ...     ...
# 5029 -0.50 -0.38 0.87   1.00 -0.53 -0.35 0.80   1.00 -0.55 -0.35  ...    0.96
# 5030 -0.50 -0.38 0.94   1.00 -0.53 -0.35 0.86   1.00 -0.55 -0.35  ...    0.93
# 5031 -0.50 -0.38 0.92   1.00 -0.53 -0.35 0.86   1.00 -0.55 -0.35  ...    0.94
# 5032 -0.50 -0.38 0.86   1.00 -0.53 -0.35 0.79   1.00 -0.55 -0.35  ...    0.88
# 5033 -0.50 -0.38 0.88   1.00 -0.53 -0.35 0.79   1.00 -0.55 -0.35  ...    0.88
#
#       19_x  19_y  19_z  19_vis  20_x  20_y  20_z  20_vis  label
# 0    -1.02 -0.99  0.56    0.07 -0.80 -0.39  1.86    0.95      0
# 1    -1.02 -1.00  0.42    0.30 -0.81 -0.40  1.62    0.98      0
# 2    -1.02 -1.00  0.39    0.18 -0.81 -0.40  1.59    0.98      0
# 3    -1.03 -1.00  0.35    0.23 -0.80 -0.40  1.46    0.98      0
# 4    -1.03 -1.01  0.39    0.14 -0.80 -0.40  1.73    0.98      0
# ...    ...   ...   ...     ...   ...   ...   ...     ...    ...
# 5029 -0.73 -1.00  0.80    0.98 -0.36 -0.70  1.34    0.97      5
# 5030 -0.73 -1.00  0.83    0.95 -0.34 -0.70  1.43    0.94      5
# 5031 -0.72 -1.00  0.83    0.96 -0.34 -0.70  1.49    0.95      5
# 5032 -0.72 -1.00  0.79    0.93 -0.34 -0.70  1.42    0.90      5
# 5033 -0.71 -1.00  0.79    0.90 -0.33 -0.68  1.45    0.90      5
#
# [5034 rows x 85 columns]

# %%
for i in data:
    if '_x' not in i:
        if '_y' not in i:
            if 'label' not in i:
                data.drop([i], axis = 1, inplace = True)

# %%
data
# Out:
#        0_x   0_y   1_x   1_y   2_x   2_y   3_x   3_y   4_x   4_y  ...  16_x  \
# 0    -0.63 -0.36 -0.66 -0.34 -0.68 -0.33 -0.70 -0.33 -0.59 -0.34  ... -0.74
# 1    -0.64 -0.36 -0.66 -0.34 -0.68 -0.33 -0.71 -0.33 -0.60 -0.34  ... -0.74
# 2    -0.64 -0.36 -0.66 -0.34 -0.68 -0.33 -0.71 -0.33 -0.60 -0.34  ... -0.74
# 3    -0.63 -0.36 -0.66 -0.33 -0.68 -0.33 -0.70 -0.33 -0.60 -0.34  ... -0.73
# 4    -0.64 -0.36 -0.66 -0.34 -0.69 -0.33 -0.71 -0.33 -0.60 -0.34  ... -0.73
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 5029 -0.50 -0.38 -0.53 -0.35 -0.55 -0.35 -0.58 -0.35 -0.48 -0.35  ... -0.25
# 5030 -0.50 -0.38 -0.53 -0.35 -0.55 -0.35 -0.57 -0.35 -0.48 -0.35  ... -0.24
# 5031 -0.50 -0.38 -0.53 -0.35 -0.55 -0.35 -0.57 -0.35 -0.47 -0.35  ... -0.24
# 5032 -0.50 -0.38 -0.53 -0.35 -0.55 -0.35 -0.57 -0.35 -0.47 -0.36  ... -0.24
# 5033 -0.50 -0.38 -0.53 -0.35 -0.55 -0.35 -0.57 -0.35 -0.47 -0.36  ... -0.23
#
#       16_y  17_x  17_y  18_x  18_y  19_x  19_y  20_x  20_y
# 0    -0.46 -1.04 -0.99 -0.80 -0.41 -1.02 -0.99 -0.80 -0.39
# 1    -0.47 -1.04 -1.00 -0.81 -0.42 -1.02 -1.00 -0.81 -0.40
# 2    -0.47 -1.04 -1.00 -0.81 -0.43 -1.02 -1.00 -0.81 -0.40
# 3    -0.47 -1.04 -1.00 -0.80 -0.43 -1.03 -1.00 -0.80 -0.40
# 4    -0.47 -1.05 -1.01 -0.80 -0.43 -1.03 -1.01 -0.80 -0.40
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 5029 -0.70 -0.78 -1.01 -0.32 -0.74 -0.73 -1.00 -0.36 -0.70
# 5030 -0.70 -0.78 -1.01 -0.30 -0.74 -0.73 -1.00 -0.34 -0.70
# 5031 -0.70 -0.77 -1.01 -0.29 -0.73 -0.72 -1.00 -0.34 -0.70
# 5032 -0.70 -0.77 -1.00 -0.30 -0.73 -0.72 -1.00 -0.34 -0.70
# 5033 -0.69 -0.76 -1.00 -0.29 -0.71 -0.71 -1.00 -0.33 -0.68
#
# [5034 rows x 42 columns]

# %%
labels = data['label']
data.drop(['label'], axis = 1, inplace = True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, labels,test_size=.2)

# %%
from lazypredict.Supervised import LazyClassifier

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:14<00:00,  1.95it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LabelPropagation                   1.00               1.00    None      1.00
# LabelSpreading                     1.00               1.00    None      1.00
# ExtraTreesClassifier               0.99               0.99    None      0.99
# XGBClassifier                      0.99               0.99    None      0.99
# RandomForestClassifier             0.99               0.99    None      0.99
# LGBMClassifier                     0.99               0.99    None      0.99
# BaggingClassifier                  0.98               0.98    None      0.98
# KNeighborsClassifier               0.98               0.98    None      0.98
# SVC                                0.97               0.97    None      0.97
# QuadraticDiscriminantAnalysis      0.96               0.96    None      0.96
# DecisionTreeClassifier             0.96               0.96    None      0.96
# ExtraTreeClassifier                0.94               0.94    None      0.94
# LinearSVC                          0.92               0.92    None      0.92
# LogisticRegression                 0.92               0.92    None      0.92
# CalibratedClassifierCV             0.92               0.92    None      0.92
# LinearDiscriminantAnalysis         0.91               0.91    None      0.91
# NuSVC                              0.90               0.90    None      0.90
# SGDClassifier                      0.90               0.90    None      0.90
# PassiveAggressiveClassifier        0.89               0.89    None      0.89
# RidgeClassifierCV                  0.89               0.89    None      0.89
# RidgeClassifier                    0.88               0.88    None      0.87
# Perceptron                         0.86               0.86    None      0.86
# GaussianNB                         0.79               0.80    None      0.79
# NearestCentroid                    0.73               0.74    None      0.73
# BernoulliNB                        0.69               0.69    None      0.68
# AdaBoostClassifier                 0.42               0.40    None      0.31
# DummyClassifier                    0.15               0.15    None      0.15
#
#                                Time Taken
# Model
# LabelPropagation                     0.96
# LabelSpreading                       1.17
# ExtraTreesClassifier                 0.33
# XGBClassifier                        1.58
# RandomForestClassifier               1.18
# LGBMClassifier                       1.82
# BaggingClassifier                    0.66
# KNeighborsClassifier                 0.11
# SVC                                  0.28
# QuadraticDiscriminantAnalysis        0.12
# DecisionTreeClassifier               0.12
# ExtraTreeClassifier                  0.02
# LinearSVC                            0.70
# LogisticRegression                   0.25
# CalibratedClassifierCV               2.75
# LinearDiscriminantAnalysis           0.05
# NuSVC                                1.39
# SGDClassifier                        0.12
# PassiveAggressiveClassifier          0.06
# RidgeClassifierCV                    0.05
# RidgeClassifier                      0.02
# Perceptron                           0.04
# GaussianNB                           0.02
# NearestCentroid                      0.02
# BernoulliNB                          0.02
# AdaBoostClassifier                   1.01
# DummyClassifier                      0.02

# %%
from sklearn.ensemble import ExtraTreesClassifier
clf = ExtraTreesClassifier(n_estimators=100, random_state=0)
clf.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(random_state=0)

# %%
print("train accuracy = ", int(clf.score(X_train, y_train)*100),"%")
# Out:
# train accuracy =  100 %

# %%
print("total cases = ", len(X_test))
right = 0
wrong = 0
y_pred = clf.predict(X_test)
for i in range(len(X_test)):
    if (y_pred[i] == y_test.values[i]):
        right += 1
    else:
        wrong += 1
print("right = ", right)
print("wrong = ", wrong)
print("test accuracy = ", int((len(X_test)/right)*100),"%")
# Out:
# total cases =  1007
# right =  1000
# wrong =  7
# test accuracy =  100 %
